# %%
from astropy import units as u
from astropy.table import Table
from astropy.coordinates import SkyCoord, ICRS
from astropy.time import Time

# %%
# Testing table ephemerides
table = Table({
    "time": [1, 2, 3, 4, 5] * u.d,
    "ra": [1, 2, 3, 4, 5] * u.deg,
    "dec": [1, 2, 3, 4, 5] * u.deg,
    "distance": [1, 2, 3, 4, 5] * u.au
  })

# %%
list(table['time'])
# Out:
# [np.float64(1.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(5.0)]

# %%
coords = SkyCoord(
  ra=[1,2,3] * u.deg,
  dec=[1,2,3] * u.deg,
  distance=[1,2,3] * u.au,
  frame="icrs"
)

# %%
coords.ra.value
# Out:
# array([1., 2., 3.])

# %%
coords[0].ra.value
# Out:
# np.float64(1.0)

# %%
coords.ra.unit
# Out:
# Unit("deg")

# %%
isinstance(coords.frame, ICRS)
# Out:
# True

# %%
a = Time([1,2,3,4,5,6], format='jd')

# %%
a[1].value
# Out:
# np.float64(2.0)

# %%
for i,t in enumerate(a):
  print(type(t.value))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
