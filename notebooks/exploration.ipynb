# %%
from astropy import units as u
from astropy.table import Table

# %%
# Testing table ephemerides
table = Table({
  "time": [1, 2, 3, 4],
  "ra": [0, 0, 0, 0],
  "dec": [0, 0, 0, 0],
  "distance": [0, 0, 0, 0]
})

# %%
cols = ['time', 'ra']
all(col in table.columns for col in cols)
# Out:
# True
